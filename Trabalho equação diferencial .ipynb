# %% [markdown]
# <a href="https://colab.research.google.com/github/Vava1706/Vava1706/blob/main/Trabalho%20equa%C3%A7%C3%A3o%20diferencial%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $$ Número 1 $$

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %%
n=15

y=np.linspace(1,5,n)
t=np.linspace(1,5,n)

Y,T = np.meshgrid(y,t)

f=2-Y

ang = np.arctan(f)
dy = np.cos(ang)
dt = np.sin(ang)

plt.quiver(T,Y,dy,dt)

# %%
n=15

y=np.linspace(1,5,n)
t=np.linspace(1,5,n)

Y,T = np.meshgrid(y,t)

f=Y-2

ang = np.arctan(f)
dy = np.cos(ang)
dt = np.sin(ang)

plt.quiver(T,Y,dy,dt)

# %%
n=15

y=np.linspace(-4,4,n)
t=np.linspace(-4,4,n)

Y,T = np.meshgrid(y,t)

f=-2-Y

ang = np.arctan(f)
dy = np.cos(ang)
dt = np.sin(ang)

plt.quiver(T,Y,dy,dt)

# %%
cs = [1, 15, 0.5, 7,8]
x = sp.Symbol("x")
f = sp.Function("f")(x)
ed = sp.Eq(f.diff(),0.5*f-450)

sol = sp.dsolve(ed,f)
fd = sol.rhs

c1, _ =tuple(fd.free_symbols)

for i in cs:
  s = fd.subs(c1,i)
  sp.plot(s, show=true)

# %%
from sympy import *
import numpy as np

# %%
x = Symbol ('x')
f = 3*x+x**2
res = diff(f,x)
#res = f.diff(x)
res
# Out:
# 2*x + 3
